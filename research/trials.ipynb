# %%
# config box
d = {"key":"val", "key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key1
# Out:
# 'val1'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d)
# Out:
# dict

# %%
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %%
get_prodict(x=2, y="3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)
# Out:
# 6

# %% [markdown]
# #Download data from drive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1k18u-BMJCfMwpAr5fBCf1NEvoMi8Tfm9/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1k18u-BMJCfMwpAr5fBCf1NEvoMi8Tfm9'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-ct-scan-image.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1k18u-BMJCfMwpAr5fBCf1NEvoMi8Tfm9
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1k18u-BMJCfMwpAr5fBCf1NEvoMi8Tfm9&confirm=t&uuid=9c667f5c-b3aa-4ab3-ba1c-385f078a9130
# To: c:\Users\DIPNA\Desktop\Kidny\Kidney_Disease_Classification\research\kidney-ct-scan-image.zip
# 100%|██████████| 57.7M/57.7M [00:27<00:00, 2.08MB/s]
# 'kidney-ct-scan-image.zip'
